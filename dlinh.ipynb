# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read data
df = pd.read_excel("Cleaned_Insurance_Claims_Data_2.xlsx", sheet_name="Claims Announcements")

# %%
df = df.assign(
    ClosingDate = lambda x: pd.to_datetime(x["ClosingDate"]),
    processTime = lambda x: (x['ClosingDate'] - x["AnnouncementDate"]).dt.days
) # Calculate process time
df = df.loc[df["ClosingDate"].dt.year < 2099] # loai dlieu 2099

# %%
product = pd.read_excel("Cleaned_Insurance_Claims_Data_2.xlsx", sheet_name="Products")

# %%
df = pd.merge(df, product, how='left', on="ProductID")

# %%
df
# Out:
#        ClaimID   ClaimCode  PolicyID   PolicyCode AnnouncementDate  EventDate  \
# 0       385398  Clm-385398    807778   Pol-807778       2018-05-22 2018-05-19
# 1       340182  Clm-340182    807800   Pol-807800       2017-10-20 2017-10-10
# 2       418588  Clm-418588    807800   Pol-807800       2018-11-05 2018-11-02
# 3       471930  Clm-471930    807800   Pol-807800       2019-06-03 2019-05-29
# 4       516031  Clm-516031    807800   Pol-807800       2019-11-27 2019-10-11
# ...        ...         ...       ...          ...              ...        ...
# 10531   533089  Clm-533089   8888576  Pol-8888576       2020-02-20 2020-01-29
# 10532   533088  Clm-533088   8888577  Pol-8888577       2020-02-20 2020-01-28
# 10533   539976  Clm-539976   8915528  Pol-8915528       2020-03-16 2020-02-03
# 10534   526048  Clm-526048   8919887  Pol-8919887       2020-01-10 2019-12-26
# 10535   533096  Clm-533096   8983841  Pol-8983841       2020-02-21 2020-01-28
#
#       ClosingDate  LastForecastAmount  BrokerID  InsuredID  ProductID  \
# 0      2018-08-30            25296.46       394     386585         58
# 1      2017-11-20             3700.00       394      19191         58
# 2      2019-05-20              257.24       394      19191         58
# 3      2020-03-04            11062.23       394      19191         58
# 4      2019-12-10              500.00       394      19191         58
# ...           ...                 ...       ...        ...        ...
# 10531  2020-03-23               25.00     11119    2524277         58
# 10532  2020-03-23               25.00     11119    2524278         58
# 10533  2020-03-17              210.03     11071    2525783         58
# 10534  2020-04-03              206.52     12333     126848         58
# 10535  2020-04-01              280.00     11217    2539607         56
#
#        processTime ProductCategory ProductSubCategory  Product
# 0              100          Health      Hospital Care  HHC-058
# 1               31          Health      Hospital Care  HHC-058
# 2              196          Health      Hospital Care  HHC-058
# 3              275          Health      Hospital Care  HHC-058
# 4               13          Health      Hospital Care  HHC-058
# ...            ...             ...                ...      ...
# 10531           32          Health      Hospital Care  HHC-058
# 10532           32          Health      Hospital Care  HHC-058
# 10533            1          Health      Hospital Care  HHC-058
# 10534           84          Health      Hospital Care  HHC-058
# 10535           40          Health    Outpatient Care  HOC-056
#
# [10536 rows x 15 columns]

# %%
# Đo lường thời gian xử lý yêu cầu và xác định những yếu tố làm chậm quy trình
## Thời gian xử lý trung bình bao lâu? 
## Yêu cầu nào chậm nhất?
## Có thể rút ngắn không?

## Biểu đồ sử dụng: Histogram thời gian xử lý, boxplot theo loại yêu cầu, scatter thời gian vs tiền, timeline quy trình

# %%
plt.figure(figsize=(10,6)) # Chỉnh kích thước hình
sns.histplot(data=df.head(10), x="processTime")
plt.title("Process time") 
plt.xlabel("Days")
plt.ylabel("Number of claims")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="processTime", y="ProductCategory")
plt.title("Process time by Category")
plt.xlabel("Days")
plt.ylabel("Category")
plt.show()

# %%
plt.figure(figsize=(10,6)) 
sns.boxplot(data=df, x="processTime", y="ProductSubCategory")
plt.title("Process time by Category")
plt.xlabel("Days")
plt.ylabel("Sub Category")
plt.show()

# %%
plt.figure(figsize=(10,6)) 
sns.scatterplot(data=df, x="processTime", y="LastForecastAmount")
plt.xlabel("Days")
plt.ylabel("Amount")
plt.show()
